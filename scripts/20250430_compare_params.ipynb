# %%
from flatten_parser import FlattenLogParser

# %%
parser = FlattenLogParser("test_params/lh.REDACTED_SUBJ_autoflatten_distances2020_n80_dilate1_passes3.flat.patch.3d.out")

# %%
parser.summarize()
data_df = parser.to_dataframe()

# %%
parser.plot_metrics(metrics=['sse', 'dist_error', 'neg_triangles'])
